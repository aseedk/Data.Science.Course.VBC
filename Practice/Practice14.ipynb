# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataframe = pd.read_csv("PracticeData/AmesHousing.csv")
dataframe
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
X = dataframe.drop("SalePrice", axis=1)
Y = dataframe["SalePrice"]
print(X.shape)
print(Y.shape)
# Out:
# (2930, 81)
# (2930,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state=51)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (2344, 81)
# (586, 81)
# (2344,)
# (586,)

# %%
dataframe = pd.read_csv("PracticeData/Iris Dataset.csv")
dataframe
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
X = dataframe.drop("species", axis=1)
Y = dataframe["species"]
print(X.shape)
print(Y.shape)
# Out:
# (150, 4)
# (150,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2, random_state=51)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
print(X_train)
print(X_test)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)
#      sepal_length  sepal_width  petal_length  petal_width
# 50            7.0          3.2           4.7          1.4
# 64            5.6          2.9           3.6          1.3
# 42            4.4          3.2           1.3          0.2
# 59            5.2          2.7           3.9          1.4
# 93            5.0          2.3           3.3          1.0
# ..            ...          ...           ...          ...
# 110           6.5          3.2           5.1          2.0
# 122           7.7          2.8           6.7          2.0
# 105           7.6          3.0           6.6          2.1
# 16            5.4          3.9           1.3          0.4
# 57            4.9          2.4           3.3          1.0
#
# [120 rows x 4 columns]
#      sepal_length  sepal_width  petal_length  petal_width
# 78            6.0          2.9           4.5          1.5
# 121           5.6          2.8           4.9          2.0
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
standardScaler = StandardScaler()
standardScaler.fit(X_train)
X_train_sc = standardScaler.transform(X_train)
standardScaler.fit(X_test)
X_test_sc = standardScaler.transform(X_test)

# %%
X_train_sc = pd.DataFrame(X_train_sc, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
X_test_sc = pd.DataFrame(X_test_sc, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])

# %%
import seaborn as sns
sns.pairplot(X_train)

# %%
sns.pairplot(X_train_sc)

# %%
sns.pairplot(X_test)

# %%
sns.pairplot(X_test_sc)

# %%
from sklearn.preprocessing import MinMaxScaler
standardScaler = MinMaxScaler()
standardScaler.fit(X_train)
X_train_sc = standardScaler.transform(X_train)
standardScaler.fit(X_test)
X_test_sc = standardScaler.transform(X_test)
X_train_sc = pd.DataFrame(X_train_sc, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
X_test_sc = pd.DataFrame(X_test_sc, columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])

# %%
sns.pairplot(X_train)

# %%
sns.pairplot(X_train_sc)

# %%
sns.pairplot(X_test)

# %%
sns.pairplot(X_test_sc)
